# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\kashr\Documents\IRCTC internship project\Railway Ticket Confirmation.csv")

# %%
df
# Out:
#           PNR Number  Train Number Date of Journey Class of Travel  \
# 0      PNR0000000000         51450      2024-09-01             3AC
# 1      PNR0000000001         54807      2024-09-02             3AC
# 2      PNR0000000002         14396      2024-09-03             3AC
# 3      PNR0000000003         20295      2024-09-04             3AC
# 4      PNR0000000004         48598      2024-09-05             2AC
# ...              ...           ...             ...             ...
# 29995  PNR0000029995         38801      2106-10-17             3AC
# 29996  PNR0000029996         99609      2106-10-18             1AC
# 29997  PNR0000029997         46802      2106-10-19         Sleeper
# 29998  PNR0000029998         94878      2106-10-20         Sleeper
# 29999  PNR0000029999         41976      2106-10-21             3AC
#
#                 Quota Source Station Destination Station Booking Date  \
# 0             General           NDLS                CSMT   2024-01-01
# 1      Premium Tatkal           MMCT                 LTT   2024-01-02
# 2              Ladies            GKP                 BBS   2024-01-03
# 3              Ladies            ASR                KOAA   2024-01-04
# 4              Tatkal            MAS                 SBC   2024-01-05
# ...               ...            ...                 ...          ...
# 29995          Tatkal            BCT                CSMT   2106-02-15
# 29996         General           MMCT                 NJP   2106-02-16
# 29997         General             JP                 MAS   2106-02-17
# 29998         General            BSB                 CNB   2106-02-18
# 29999         General            GKP                MMCT   2106-02-19
#
#       Current Status  Number of Passengers  ... Booking Channel  \
# 0          Confirmed                     4  ...         Counter
# 1         Waitlisted                     5  ...      Mobile App
# 2                RAC                     5  ...   IRCTC Website
# 3         Waitlisted                     1  ...         Counter
# 4          Confirmed                     3  ...      Mobile App
# ...              ...                   ...  ...             ...
# 29995      Confirmed                     5  ...      Mobile App
# 29996            RAC                     4  ...      Mobile App
# 29997     Waitlisted                     3  ...   IRCTC Website
# 29998     Waitlisted                     4  ...         Counter
# 29999            RAC                     5  ...         Counter
#
#       Travel Distance  Number of Stations  Travel Time  Train Type  \
# 0                1656                  17           37    Shatabdi
# 1                1932                  18            6    Shatabdi
# 2                 155                   4           17     Express
# 3                1840                   5           16   Superfast
# 4                1766                   9           32     Express
# ...               ...                 ...          ...         ...
# 29995            1451                   2            9    Rajdhani
# 29996            1581                  16            3    Shatabdi
# 29997             963                  15           12    Shatabdi
# 29998             830                   8            7     Express
# 29999            1220                   8           33    Shatabdi
#
#       Seat Availability  Special Considerations Holiday or Peak Season  \
# 0                   159          Senior Citizen                    Yes
# 1                   309                     NaN                    Yes
# 2                   143                     NaN                    Yes
# 3                   256          Senior Citizen                     No
# 4                    58                     NaN                    Yes
# ...                 ...                     ...                    ...
# 29995               409                     NaN                     No
# 29996                90          Senior Citizen                     No
# 29997               110                     NaN                    Yes
# 29998                91                     NaN                     No
# 29999               331                     NaN                    Yes
#
#       Waitlist Position Confirmation Status
# 0                   NaN           Confirmed
# 1                 WL097       Not Confirmed
# 2                   NaN           Confirmed
# 3                 WL011       Not Confirmed
# 4                   NaN           Confirmed
# ...                 ...                 ...
# 29995               NaN           Confirmed
# 29996               NaN           Confirmed
# 29997             WL097       Not Confirmed
# 29998             WL006       Not Confirmed
# 29999               NaN           Confirmed
#
# [30000 rows x 21 columns]

# %%
df['Date of Journey']=pd.to_datetime(df['Date of Journey'])

# %%
df['year']=df['Date of Journey'].dt.year

# %%
df.head()
# Out:
#       PNR Number  Train Number Date of Journey Class of Travel  \
# 0  PNR0000000000         51450      2024-09-01             3AC
# 1  PNR0000000001         54807      2024-09-02             3AC
# 2  PNR0000000002         14396      2024-09-03             3AC
# 3  PNR0000000003         20295      2024-09-04             3AC
# 4  PNR0000000004         48598      2024-09-05             2AC
#
#             Quota Source Station Destination Station Booking Date  \
# 0         General           NDLS                CSMT   2024-01-01
# 1  Premium Tatkal           MMCT                 LTT   2024-01-02
# 2          Ladies            GKP                 BBS   2024-01-03
# 3          Ladies            ASR                KOAA   2024-01-04
# 4          Tatkal            MAS                 SBC   2024-01-05
#
#   Current Status  Number of Passengers  ... Travel Distance  \
# 0      Confirmed                     4  ...            1656
# 1     Waitlisted                     5  ...            1932
# 2            RAC                     5  ...             155
# 3     Waitlisted                     1  ...            1840
# 4      Confirmed                     3  ...            1766
#
#   Number of Stations  Travel Time  Train Type  Seat Availability  \
# 0                 17           37    Shatabdi                159
# 1                 18            6    Shatabdi                309
# 2                  4           17     Express                143
# 3                  5           16   Superfast                256
# 4                  9           32     Express                 58
#
#   Special Considerations  Holiday or Peak Season Waitlist Position  \
# 0         Senior Citizen                     Yes               NaN
# 1                    NaN                     Yes             WL097
# 2                    NaN                     Yes               NaN
# 3         Senior Citizen                      No             WL011
# 4                    NaN                     Yes               NaN
#
#   Confirmation Status  year
# 0           Confirmed  2024
# 1       Not Confirmed  2024
# 2           Confirmed  2024
# 3       Not Confirmed  2024
# 4           Confirmed  2024
#
# [5 rows x 22 columns]

# %%
# pd.set_option('display.max_rows',None)
df['year'].unique()
# Out:
# array([2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034,
#        2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045,
#        2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056,
#        2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067,
#        2068, 2069, 2070, 2071, 2072, 2073, 2074, 2075, 2076, 2077, 2078,
#        2079, 2080, 2081, 2082, 2083, 2084, 2085, 2086, 2087, 2088, 2089,
#        2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100,
#        2101, 2102, 2103, 2104, 2105, 2106])

# %%
df.shape
# Out:
# (30000, 22)

# %%
df['year'].sort_values(ascending=True)
# Out:
# 0        2024
# 89       2024
# 88       2024
# 87       2024
# 86       2024
#          ...
# 29800    2106
# 29799    2106
# 29798    2106
# 29814    2106
# 29999    2106
# Name: year, Length: 30000, dtype: int32

# %%
df
# Out:
#           PNR Number  Train Number Date of Journey Class of Travel  \
# 0      PNR0000000000         51450      2024-09-01             3AC
# 1      PNR0000000001         54807      2024-09-02             3AC
# 2      PNR0000000002         14396      2024-09-03             3AC
# 3      PNR0000000003         20295      2024-09-04             3AC
# 4      PNR0000000004         48598      2024-09-05             2AC
# ...              ...           ...             ...             ...
# 29995  PNR0000029995         38801      2106-10-17             3AC
# 29996  PNR0000029996         99609      2106-10-18             1AC
# 29997  PNR0000029997         46802      2106-10-19         Sleeper
# 29998  PNR0000029998         94878      2106-10-20         Sleeper
# 29999  PNR0000029999         41976      2106-10-21             3AC
#
#                 Quota Source Station Destination Station Booking Date  \
# 0             General           NDLS                CSMT   2024-01-01
# 1      Premium Tatkal           MMCT                 LTT   2024-01-02
# 2              Ladies            GKP                 BBS   2024-01-03
# 3              Ladies            ASR                KOAA   2024-01-04
# 4              Tatkal            MAS                 SBC   2024-01-05
# ...               ...            ...                 ...          ...
# 29995          Tatkal            BCT                CSMT   2106-02-15
# 29996         General           MMCT                 NJP   2106-02-16
# 29997         General             JP                 MAS   2106-02-17
# 29998         General            BSB                 CNB   2106-02-18
# 29999         General            GKP                MMCT   2106-02-19
#
#       Current Status  Number of Passengers  ... Travel Distance  \
# 0          Confirmed                     4  ...            1656
# 1         Waitlisted                     5  ...            1932
# 2                RAC                     5  ...             155
# 3         Waitlisted                     1  ...            1840
# 4          Confirmed                     3  ...            1766
# ...              ...                   ...  ...             ...
# 29995      Confirmed                     5  ...            1451
# 29996            RAC                     4  ...            1581
# 29997     Waitlisted                     3  ...             963
# 29998     Waitlisted                     4  ...             830
# 29999            RAC                     5  ...            1220
#
#       Number of Stations  Travel Time  Train Type  Seat Availability  \
# 0                     17           37    Shatabdi                159
# 1                     18            6    Shatabdi                309
# 2                      4           17     Express                143
# 3                      5           16   Superfast                256
# 4                      9           32     Express                 58
# ...                  ...          ...         ...                ...
# 29995                  2            9    Rajdhani                409
# 29996                 16            3    Shatabdi                 90
# 29997                 15           12    Shatabdi                110
# 29998                  8            7     Express                 91
# 29999                  8           33    Shatabdi                331
#
#       Special Considerations  Holiday or Peak Season Waitlist Position  \
# 0             Senior Citizen                     Yes               NaN
# 1                        NaN                     Yes             WL097
# 2                        NaN                     Yes               NaN
# 3             Senior Citizen                      No             WL011
# 4                        NaN                     Yes               NaN
# ...                      ...                     ...               ...
# 29995                    NaN                      No               NaN
# 29996         Senior Citizen                      No               NaN
# 29997                    NaN                     Yes             WL097
# 29998                    NaN                      No             WL006
# 29999                    NaN                     Yes               NaN
#
#       Confirmation Status  year
# 0               Confirmed  2024
# 1           Not Confirmed  2024
# 2               Confirmed  2024
# 3           Not Confirmed  2024
# 4               Confirmed  2024
# ...                   ...   ...
# 29995           Confirmed  2106
# 29996           Confirmed  2106
# 29997       Not Confirmed  2106
# 29998       Not Confirmed  2106
# 29999           Confirmed  2106
#
# [30000 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# PNR Number                    0
# Train Number                  0
# Date of Journey               0
# Class of Travel               0
# Quota                         0
# Source Station                0
# Destination Station           0
# Booking Date                  0
# Current Status                0
# Number of Passengers          0
# Age of Passengers             0
# Booking Channel               0
# Travel Distance               0
# Number of Stations            0
# Travel Time                   0
# Train Type                    0
# Seat Availability             0
# Special Considerations     9955
# Holiday or Peak Season        0
# Waitlist Position         19947
# Confirmation Status           0
# year                          0
# dtype: int64

# %%
# Step 1: Get the unique years and sort them in ascending order
unique_years = sorted(df['year'].unique(), reverse=False)

# Step 2: Create a mapping from the highest unique year (which should remain 2024) to descending years
year_mapping = {year: 2024 - i for i, year in enumerate(unique_years)}

# Step 3: Replace the years in the DataFrame with the new mapping
df['year'] = df['year'].map(year_mapping)

# Step 4: Verify the results
print(df['year'].unique())  # This should now show the mapped years starting from 2024 and descending
# Out:
# [2024 2023 2022 2021 2020 2019 2018 2017 2016 2015 2014 2013 2012 2011
#  2010 2009 2008 2007 2006 2005 2004 2003 2002 2001 2000 1999 1998 1997
#  1996 1995 1994 1993 1992 1991 1990 1989 1988 1987 1986 1985 1984 1983
#  1982 1981 1980 1979 1978 1977 1976 1975 1974 1973 1972 1971 1970 1969
#  1968 1967 1966 1965 1964 1963 1962 1961 1960 1959 1958 1957 1956 1955
#  1954 1953 1952 1951 1950 1949 1948 1947 1946 1945 1944 1943 1942]

# %%
df.head()
# Out:
#       PNR Number  Train Number Date of Journey Class of Travel  \
# 0  PNR0000000000         51450      2024-09-01             3AC
# 1  PNR0000000001         54807      2024-09-02             3AC
# 2  PNR0000000002         14396      2024-09-03             3AC
# 3  PNR0000000003         20295      2024-09-04             3AC
# 4  PNR0000000004         48598      2024-09-05             2AC
#
#             Quota Source Station Destination Station Booking Date  \
# 0         General           NDLS                CSMT   2024-01-01
# 1  Premium Tatkal           MMCT                 LTT   2024-01-02
# 2          Ladies            GKP                 BBS   2024-01-03
# 3          Ladies            ASR                KOAA   2024-01-04
# 4          Tatkal            MAS                 SBC   2024-01-05
#
#   Current Status  Number of Passengers  ... Travel Distance  \
# 0      Confirmed                     4  ...            1656
# 1     Waitlisted                     5  ...            1932
# 2            RAC                     5  ...             155
# 3     Waitlisted                     1  ...            1840
# 4      Confirmed                     3  ...            1766
#
#   Number of Stations  Travel Time  Train Type  Seat Availability  \
# 0                 17           37    Shatabdi                159
# 1                 18            6    Shatabdi                309
# 2                  4           17     Express                143
# 3                  5           16   Superfast                256
# 4                  9           32     Express                 58
#
#   Special Considerations  Holiday or Peak Season Waitlist Position  \
# 0         Senior Citizen                     Yes               NaN
# 1                    NaN                     Yes             WL097
# 2                    NaN                     Yes               NaN
# 3         Senior Citizen                      No             WL011
# 4                    NaN                     Yes               NaN
#
#   Confirmation Status  year
# 0           Confirmed  2024
# 1       Not Confirmed  2024
# 2           Confirmed  2024
# 3       Not Confirmed  2024
# 4           Confirmed  2024
#
# [5 rows x 22 columns]

# %%
# Step 1: Convert 'date_of_journey' to datetime 
df['Date of Journey'] = pd.to_datetime(df['Date of Journey'], errors='coerce')

# Step 2: Extract the year from 'date_of_journey'
df['journey_year'] = df['Date of Journey'].dt.year

# Step 3: Map the years in 'journey_year' using the 'year_mapping' dictionary
df['journey_year_mapped'] = df['journey_year'].map(year_mapping)

# Step 4: Replace the year in 'date_of_journey' with the mapped year only if 'journey_year_mapped' is not NaN
df['Date of Journey'] = df.apply(
    lambda x: x['Date of Journey'].replace(year=int(x['journey_year_mapped'])) 
    if pd.notnull(x['journey_year_mapped']) else x['Date of Journey'], 
    axis=1
)

# Step 5: Drop the temporary 'journey_year' and 'journey_year_mapped' columns
df.drop(columns=['journey_year', 'journey_year_mapped'], inplace=True)

# Step 6: Verify the changes
print(df['Date of Journey'].head())
# Out:
# 0   2024-09-01
# 1   2024-09-02
# 2   2024-09-03
# 3   2024-09-04
# 4   2024-09-05
# Name: Date of Journey, dtype: datetime64[ns]

# %%
df.head()
# Out:
#       PNR Number  Train Number Date of Journey Class of Travel  \
# 0  PNR0000000000         51450      2024-09-01             3AC
# 1  PNR0000000001         54807      2024-09-02             3AC
# 2  PNR0000000002         14396      2024-09-03             3AC
# 3  PNR0000000003         20295      2024-09-04             3AC
# 4  PNR0000000004         48598      2024-09-05             2AC
#
#             Quota Source Station Destination Station Booking Date  \
# 0         General           NDLS                CSMT   2024-01-01
# 1  Premium Tatkal           MMCT                 LTT   2024-01-02
# 2          Ladies            GKP                 BBS   2024-01-03
# 3          Ladies            ASR                KOAA   2024-01-04
# 4          Tatkal            MAS                 SBC   2024-01-05
#
#   Current Status  Number of Passengers  ... Travel Distance  \
# 0      Confirmed                     4  ...            1656
# 1     Waitlisted                     5  ...            1932
# 2            RAC                     5  ...             155
# 3     Waitlisted                     1  ...            1840
# 4      Confirmed                     3  ...            1766
#
#   Number of Stations  Travel Time  Train Type  Seat Availability  \
# 0                 17           37    Shatabdi                159
# 1                 18            6    Shatabdi                309
# 2                  4           17     Express                143
# 3                  5           16   Superfast                256
# 4                  9           32     Express                 58
#
#   Special Considerations  Holiday or Peak Season Waitlist Position  \
# 0         Senior Citizen                     Yes               NaN
# 1                    NaN                     Yes             WL097
# 2                    NaN                     Yes               NaN
# 3         Senior Citizen                      No             WL011
# 4                    NaN                     Yes               NaN
#
#   Confirmation Status  year
# 0           Confirmed  2024
# 1       Not Confirmed  2024
# 2           Confirmed  2024
# 3       Not Confirmed  2024
# 4           Confirmed  2024
#
# [5 rows x 22 columns]

# %%
df['Special Considerations'].unique()
# Out:
# array(['Senior Citizen', nan, 'Defense Quota'], dtype=object)

# %%
# Since waitlist column contains null values where the ticket is confirmed we can simply fill those null values by WL000
df['Waitlist Position']=df['Waitlist Position'].fillna('WL000')

# %%
df.isnull().sum()
# Out:
# PNR Number                   0
# Train Number                 0
# Date of Journey              0
# Class of Travel              0
# Quota                        0
# Source Station               0
# Destination Station          0
# Booking Date                 0
# Current Status               0
# Number of Passengers         0
# Age of Passengers            0
# Booking Channel              0
# Travel Distance              0
# Number of Stations           0
# Travel Time                  0
# Train Type                   0
# Seat Availability            0
# Special Considerations    9955
# Holiday or Peak Season       0
# Waitlist Position            0
# Confirmation Status          0
# year                         0
# dtype: int64

# %%
# Since Special Considerations column contains null values where no quota is applies so we will simply fill it by no quota
df['Special Considerations'].fillna('No Quota',inplace=True)
# Out:
# C:\Users\kashr\AppData\Local\Temp\ipykernel_9124\3220130621.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Special Considerations'].fillna('No Quota',inplace=True)

# %%
df.isnull().sum()
# Out:
# PNR Number                0
# Train Number              0
# Date of Journey           0
# Class of Travel           0
# Quota                     0
# Source Station            0
# Destination Station       0
# Booking Date              0
# Current Status            0
# Number of Passengers      0
# Age of Passengers         0
# Booking Channel           0
# Travel Distance           0
# Number of Stations        0
# Travel Time               0
# Train Type                0
# Seat Availability         0
# Special Considerations    0
# Holiday or Peak Season    0
# Waitlist Position         0
# Confirmation Status       0
# year                      0
# dtype: int64

# %%
df['Booking Date'].unique()
# Out:
# array(['2024-01-01', '2024-01-02', '2024-01-03', ..., '2106-02-17',
#        '2106-02-18', '2106-02-19'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PNR Number              30000 non-null  object
#  1   Train Number            30000 non-null  int64
#  2   Date of Journey         30000 non-null  datetime64[ns]
#  3   Class of Travel         30000 non-null  object
#  4   Quota                   30000 non-null  object
#  5   Source Station          30000 non-null  object
#  6   Destination Station     30000 non-null  object
#  7   Booking Date            30000 non-null  object
#  8   Current Status          30000 non-null  object
#  9   Number of Passengers    30000 non-null  int64
#  10  Age of Passengers       30000 non-null  object
#  11  Booking Channel         30000 non-null  object
#  12  Travel Distance         30000 non-null  int64
#  13  Number of Stations      30000 non-null  int64
#  14  Travel Time             30000 non-null  int64
#  15  Train Type              30000 non-null  object
#  16  Seat Availability       30000 non-null  int64
#  17  Special Considerations  30000 non-null  object
#  18  Holiday or Peak Season  30000 non-null  object
#  19  Waitlist Position       30000 non-null  object
#  20  Confirmation Status     30000 non-null  object
#  21  year                    30000 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(14)
# memory usage: 5.0+ MB

# %%
# since booking date also contain the worng year and it is also in string format
# we will do the same which we whave done with date of journey column
df['Booking Date']=pd.to_datetime(df['Booking Date'])

# %%
# Extract the year from df['Booking Date'].
df['booking_year']=df['Booking Date'].dt.year
# map the years in booking year using the year_mapping dictionary which we have created earlier
# Step 2: Create a mapping from the highest unique year (which should remain 2024) to descending years
#for reference i have copied above code- year_mapping = {year: 2024 - i for i, year in enumerate(unique_years)}
df['booking_year_mapped']=df['booking_year'].map(year_mapping)
# step3: NOw we will replace the year in booking date with the mapped year
df['Booking Date']=df.apply(lambda x:x['Booking Date'].replace(year=x['booking_year_mapped']),axis=1)
# step 4: drop the columns that we have created
df.drop(columns=['booking_year_mapped','booking_year'],inplace=True)

# %%
df['Booking Date']
# Out:
# 0       2024-01-01
# 1       2024-01-02
# 2       2024-01-03
# 3       2024-01-04
# 4       2024-01-05
#            ...
# 29995   1942-02-15
# 29996   1942-02-16
# 29997   1942-02-17
# 29998   1942-02-18
# 29999   1942-02-19
# Name: Booking Date, Length: 30000, dtype: datetime64[ns]

# %% [markdown]
# # Now we will generate features which will be helpful in our prediction like whether it is weeday or weekend, what is the month and whether it is a holiday period

# %%
df['booking_day']=df['Booking Date'].dt.weekday
df['journey_day']=df['Date of Journey'].dt.weekday
df['is_weekend']=df['Date of Journey'].dt.weekday>5
df['journey_month']=df['Date of Journey'].dt.month
df['days_to_travel']=abs(df['Date of Journey']-df['Booking Date']).dt.days

# %%
df.sample()
# Out:
#           PNR Number  Train Number Date of Journey Class of Travel  \
# 17215  PNR0000017215         76299      1977-10-20             2AC
#
#                 Quota Source Station Destination Station Booking Date  \
# 17215  Premium Tatkal            MAS                 JHS   1977-02-18
#
#       Current Status  Number of Passengers  ... Special Considerations  \
# 17215     Waitlisted                     5  ...          Defense Quota
#
#       Holiday or Peak Season  Waitlist Position  Confirmation Status  year  \
# 17215                    Yes              WL016        Not Confirmed  1977
#
#       booking_day  journey_day is_weekend journey_month days_to_travel
# 17215           4            3      False            10            244
#
# [1 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['PNR Number', 'Train Number', 'Date of Journey', 'Class of Travel',
#        'Quota', 'Source Station', 'Destination Station', 'Booking Date',
#        'Current Status', 'Number of Passengers', 'Age of Passengers',
#        'Booking Channel', 'Travel Distance', 'Number of Stations',
#        'Travel Time', 'Train Type', 'Seat Availability',
#        'Special Considerations', 'Holiday or Peak Season', 'Waitlist Position',
#        'Confirmation Status', 'year', 'booking_day', 'journey_day',
#        'is_weekend', 'journey_month', 'days_to_travel'],
#       dtype='object')

# %%
df['Destination Station'].unique()
# Out:
# array(['CSMT', 'LTT', 'BBS', 'KOAA', 'SBC', 'MMCT', 'PNBE', 'JHS', 'GKP',
#        'MAS', 'BCT', 'HWH', 'JP', 'ASR', 'NDLS', 'ADI', 'BSB', 'UMB',
#        'NJP', 'JU', 'SC', 'CNB', 'LKO'], dtype=object)

# %%
df.columns
# Out:
# Index(['PNR Number', 'Train Number', 'Date of Journey', 'Class of Travel',
#        'Quota', 'Source Station', 'Destination Station', 'Booking Date',
#        'Current Status', 'Number of Passengers', 'Age of Passengers',
#        'Booking Channel', 'Travel Distance', 'Number of Stations',
#        'Travel Time', 'Train Type', 'Seat Availability',
#        'Special Considerations', 'Holiday or Peak Season', 'Waitlist Position',
#        'Confirmation Status', 'year', 'booking_day', 'journey_day',
#        'is_weekend', 'journey_month', 'days_to_travel'],
#       dtype='object')

# %%
df.drop(columns=['PNR Number','Train Number','Date of Journey','Booking Date'],inplace=True)

# %%
df.sample()
# Out:
#       Class of Travel   Quota Source Station Destination Station  \
# 15110             2AC  Ladies           MMCT                 HWH
#
#       Current Status  Number of Passengers Age of Passengers Booking Channel  \
# 15110      Confirmed                     4             Child      Mobile App
#
#        Travel Distance  Number of Stations  ...  Special Considerations  \
# 15110              840                   7  ...                No Quota
#
#       Holiday or Peak Season  Waitlist Position Confirmation Status  year  \
# 15110                     No              WL000           Confirmed  1982
#
#       booking_day journey_day  is_weekend  journey_month  days_to_travel
# 15110           6           3       False              1             486
#
# [1 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Class of Travel         30000 non-null  object
#  1   Quota                   30000 non-null  object
#  2   Source Station          30000 non-null  object
#  3   Destination Station     30000 non-null  object
#  4   Current Status          30000 non-null  object
#  5   Number of Passengers    30000 non-null  int64
#  6   Age of Passengers       30000 non-null  object
#  7   Booking Channel         30000 non-null  object
#  8   Travel Distance         30000 non-null  int64
#  9   Number of Stations      30000 non-null  int64
#  10  Travel Time             30000 non-null  int64
#  11  Train Type              30000 non-null  object
#  12  Seat Availability       30000 non-null  int64
#  13  Special Considerations  30000 non-null  object
#  14  Holiday or Peak Season  30000 non-null  object
#  15  Waitlist Position       30000 non-null  object
#  16  Confirmation Status     30000 non-null  object
#  17  year                    30000 non-null  int64
#  18  booking_day             30000 non-null  int32
#  19  journey_day             30000 non-null  int32
#  20  is_weekend              30000 non-null  bool
#  21  journey_month           30000 non-null  int32
#  22  days_to_travel          30000 non-null  int64
# dtypes: bool(1), int32(3), int64(7), object(12)
# memory usage: 4.7+ MB

# %%
df['Age of Passengers'].unique()
# Out:
# array(['Child', 'Senior Citizen', 'Adult'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df['is_weekend']=df['is_weekend'].astype(str)

# %%
label_encoder=LabelEncoder()
for i in df.select_dtypes(include='object').columns:
    df[i]=label_encoder.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Class of Travel         30000 non-null  int32
#  1   Quota                   30000 non-null  int32
#  2   Source Station          30000 non-null  int32
#  3   Destination Station     30000 non-null  int32
#  4   Current Status          30000 non-null  int32
#  5   Number of Passengers    30000 non-null  int64
#  6   Age of Passengers       30000 non-null  int32
#  7   Booking Channel         30000 non-null  int32
#  8   Travel Distance         30000 non-null  int64
#  9   Number of Stations      30000 non-null  int64
#  10  Travel Time             30000 non-null  int64
#  11  Train Type              30000 non-null  int32
#  12  Seat Availability       30000 non-null  int64
#  13  Special Considerations  30000 non-null  int32
#  14  Holiday or Peak Season  30000 non-null  int32
#  15  Waitlist Position       30000 non-null  int32
#  16  Confirmation Status     30000 non-null  int32
#  17  year                    30000 non-null  int64
#  18  booking_day             30000 non-null  int32
#  19  journey_day             30000 non-null  int32
#  20  is_weekend              30000 non-null  int32
#  21  journey_month           30000 non-null  int32
#  22  days_to_travel          30000 non-null  int64
# dtypes: int32(16), int64(7)
# memory usage: 3.4 MB

# %%
df.sample()
# Out:
#        Class of Travel  Quota  Source Station  Destination Station  \
# 23413                2      1               0                   22
#
#        Current Status  Number of Passengers  Age of Passengers  \
# 23413               0                     3                  2
#
#        Booking Channel  Travel Distance  Number of Stations  ...  \
# 23413                1             1182                  16  ...
#
#        Special Considerations  Holiday or Peak Season  Waitlist Position  \
# 23413                       2                       1                  0
#
#        Confirmation Status  year  booking_day  journey_day  is_weekend  \
# 23413                    0  1960            6            5           0
#
#        journey_month  days_to_travel
# 23413             10             244
#
# [1 rows x 23 columns]

# %%
df.sample(3)
# Out:
#        Class of Travel  Quota  Source Station  Destination Station  \
# 15692                3      3              12                   18
# 18904                2      1              14                   19
# 2247                 0      2               6                    8
#
#        Current Status  Number of Passengers  Age of Passengers  \
# 15692               2                     5                  1
# 18904               1                     4                  2
# 2247                1                     1                  1
#
#        Booking Channel  Travel Distance  Number of Stations  ...  \
# 15692                1              259                   8  ...
# 18904                0              810                  18  ...
# 2247                 2              389                  14  ...
#
#        Special Considerations  Holiday or Peak Season  Waitlist Position  \
# 15692                       0                       1                175
# 18904                       0                       1                  0
# 2247                        1                       1                  0
#
#        Confirmation Status  year  booking_day  journey_day  is_weekend  \
# 15692                    1  1981            5            2           0
# 18904                    0  1972            3            6           1
# 2247                     0  2018            6            5           0
#
#        journey_month  days_to_travel
# 15692              8             486
# 18904              6             487
# 2247              10             244
#
# [3 rows x 23 columns]

# %%
df['Confirmation Status'].unique()
# Out:
# array([0, 1])

# %%
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
df.corr()
# Out:
#                         Class of Travel     Quota  Source Station  \
# Class of Travel                1.000000 -0.000055        0.000097
# Quota                         -0.000055  1.000000       -0.009896
# Source Station                 0.000097 -0.009896        1.000000
# Destination Station            0.003858 -0.003592        0.000257
# Current Status                 0.002937  0.005872        0.000631
# Number of Passengers          -0.012021 -0.004269        0.000011
# Age of Passengers              0.006728  0.000714        0.000915
# Booking Channel                0.004573 -0.003382       -0.000138
# Travel Distance               -0.006650 -0.012004        0.000120
# Number of Stations            -0.005741 -0.003130       -0.005553
# Travel Time                   -0.005364 -0.005073       -0.001615
# Train Type                     0.005867  0.004813        0.004482
# Seat Availability             -0.004529 -0.013820        0.006161
# Special Considerations        -0.006464  0.005905        0.005121
# Holiday or Peak Season         0.011652 -0.004620        0.007660
# Waitlist Position              0.008118  0.005906        0.004302
# Confirmation Status            0.002340  0.005306       -0.004518
# year                          -0.004055 -0.000911       -0.003889
# booking_day                    0.013710 -0.007226        0.001582
# journey_day                   -0.007264  0.006755       -0.005997
# is_weekend                    -0.009531  0.004900        0.005072
# journey_month                 -0.000903 -0.004568       -0.000748
# days_to_travel                -0.000174  0.000588        0.001022
#
#                         Destination Station  Current Status  \
# Class of Travel                    0.003858        0.002937
# Quota                             -0.003592        0.005872
# Source Station                     0.000257        0.000631
# Destination Station                1.000000       -0.000258
# Current Status                    -0.000258        1.000000
# Number of Passengers               0.003912       -0.003114
# Age of Passengers                 -0.000272        0.000952
# Booking Channel                   -0.010171       -0.009536
# Travel Distance                   -0.006888        0.006894
# Number of Stations                 0.006406       -0.005816
# Travel Time                        0.009382       -0.001445
# Train Type                        -0.003123       -0.008133
# Seat Availability                  0.006404        0.008547
# Special Considerations             0.008839       -0.010801
# Holiday or Peak Season            -0.007747        0.008506
# Waitlist Position                 -0.003900        0.704557
# Confirmation Status               -0.002298        0.866199
# year                               0.006451       -0.005457
# booking_day                       -0.001038        0.003350
# journey_day                        0.011910       -0.017159
# is_weekend                         0.005101       -0.009373
# journey_month                     -0.000888        0.009844
# days_to_travel                     0.000654       -0.007790
#
#                         Number of Passengers  Age of Passengers  \
# Class of Travel                    -0.012021           0.006728
# Quota                              -0.004269           0.000714
# Source Station                      0.000011           0.000915
# Destination Station                 0.003912          -0.000272
# Current Status                     -0.003114           0.000952
# Number of Passengers                1.000000           0.008149
# Age of Passengers                   0.008149           1.000000
# Booking Channel                    -0.002875           0.009270
# Travel Distance                    -0.001979           0.004551
# Number of Stations                  0.004124           0.007753
# Travel Time                         0.006118          -0.003600
# Train Type                          0.008115          -0.002445
# Seat Availability                  -0.002603           0.005142
# Special Considerations             -0.002426           0.005550
# Holiday or Peak Season             -0.003631          -0.009279
# Waitlist Position                  -0.009036           0.000880
# Confirmation Status                -0.004127           0.000058
# year                                0.002771          -0.001766
# booking_day                         0.003229          -0.002187
# journey_day                         0.009968          -0.000858
# is_weekend                          0.007485          -0.009244
# journey_month                       0.001889           0.003123
# days_to_travel                     -0.001461          -0.007675
#
#                         Booking Channel  Travel Distance  Number of Stations  \
# Class of Travel                0.004573        -0.006650           -0.005741
# Quota                         -0.003382        -0.012004           -0.003130
# Source Station                -0.000138         0.000120           -0.005553
# Destination Station           -0.010171        -0.006888            0.006406
# Current Status                -0.009536         0.006894           -0.005816
# Number of Passengers          -0.002875        -0.001979            0.004124
# Age of Passengers              0.009270         0.004551            0.007753
# Booking Channel                1.000000        -0.003056            0.008636
# Travel Distance               -0.003056         1.000000            0.003411
# Number of Stations             0.008636         0.003411            1.000000
# Travel Time                    0.005820        -0.000788            0.002959
# Train Type                    -0.007017         0.008157           -0.003261
# Seat Availability              0.004863        -0.006589           -0.013076
# Special Considerations         0.002796         0.001187            0.009016
# Holiday or Peak Season         0.000470        -0.000571           -0.004435
# Waitlist Position             -0.008045         0.000080            0.003943
# Confirmation Status           -0.009334         0.004482            0.001055
# year                          -0.014478        -0.007594           -0.002971
# booking_day                   -0.004189         0.006307            0.000150
# journey_day                    0.004025         0.000205            0.004733
# is_weekend                     0.002536         0.002707            0.005277
# journey_month                 -0.005244         0.005281           -0.004045
# days_to_travel                 0.001335        -0.002890            0.005066
#
#                         Travel Time  Train Type  Seat Availability  \
# Class of Travel           -0.005364    0.005867          -0.004529
# Quota                     -0.005073    0.004813          -0.013820
# Source Station            -0.001615    0.004482           0.006161
# Destination Station        0.009382   -0.003123           0.006404
# Current Status            -0.001445   -0.008133           0.008547
# Number of Passengers       0.006118    0.008115          -0.002603
# Age of Passengers         -0.003600   -0.002445           0.005142
# Booking Channel            0.005820   -0.007017           0.004863
# Travel Distance           -0.000788    0.008157          -0.006589
# Number of Stations         0.002959   -0.003261          -0.013076
# Travel Time                1.000000    0.003252          -0.001933
# Train Type                 0.003252    1.000000           0.000076
# Seat Availability         -0.001933    0.000076           1.000000
# Special Considerations    -0.006011    0.002588           0.001687
# Holiday or Peak Season    -0.003447   -0.000082          -0.001259
# Waitlist Position         -0.004087    0.000790           0.007018
# Confirmation Status       -0.002588   -0.002674           0.007971
# year                      -0.001804    0.004653          -0.004474
# booking_day                0.002706    0.000555          -0.003543
# journey_day                0.010199    0.013891          -0.000592
# is_weekend                 0.012414    0.005962           0.002860
# journey_month              0.000711   -0.009121           0.007028
# days_to_travel            -0.000950    0.007595          -0.008375
#
#                         Special Considerations  Holiday or Peak Season  \
# Class of Travel                      -0.006464                0.011652
# Quota                                 0.005905               -0.004620
# Source Station                        0.005121                0.007660
# Destination Station                   0.008839               -0.007747
# Current Status                       -0.010801                0.008506
# Number of Passengers                 -0.002426               -0.003631
# Age of Passengers                     0.005550               -0.009279
# Booking Channel                       0.002796                0.000470
# Travel Distance                       0.001187               -0.000571
# Number of Stations                    0.009016               -0.004435
# Travel Time                          -0.006011               -0.003447
# Train Type                            0.002588               -0.000082
# Seat Availability                     0.001687               -0.001259
# Special Considerations                1.000000                0.004195
# Holiday or Peak Season                0.004195                1.000000
# Waitlist Position                    -0.006992                0.006777
# Confirmation Status                  -0.012242                0.007016
# year                                  0.004460               -0.004815
# booking_day                           0.001672                0.014867
# journey_day                           0.006830               -0.002050
# is_weekend                            0.006259                0.001007
# journey_month                        -0.012988                0.000271
# days_to_travel                        0.013568                0.003763
#
#                         Waitlist Position  Confirmation Status      year  \
# Class of Travel                  0.008118             0.002340 -0.004055
# Quota                            0.005906             0.005306 -0.000911
# Source Station                   0.004302            -0.004518 -0.003889
# Destination Station             -0.003900            -0.002298  0.006451
# Current Status                   0.704557             0.866199 -0.005457
# Number of Passengers            -0.009036            -0.004127  0.002771
# Age of Passengers                0.000880             0.000058 -0.001766
# Booking Channel                 -0.008045            -0.009334 -0.014478
# Travel Distance                  0.000080             0.004482 -0.007594
# Number of Stations               0.003943             0.001055 -0.002971
# Travel Time                     -0.004087            -0.002588 -0.001804
# Train Type                       0.000790            -0.002674  0.004653
# Seat Availability                0.007018             0.007971 -0.004474
# Special Considerations          -0.006992            -0.012242  0.004460
# Holiday or Peak Season           0.006777             0.007016 -0.004815
# Waitlist Position                1.000000             0.813389 -0.009974
# Confirmation Status              0.813389             1.000000 -0.004517
# year                            -0.009974            -0.004517  1.000000
# booking_day                      0.004145             0.002990 -0.000016
# journey_day                     -0.008745            -0.008768  0.000072
# is_weekend                      -0.007142            -0.007717  0.000263
# journey_month                    0.002211             0.007442  0.013760
# days_to_travel                  -0.000751            -0.005934 -0.015785
#
#                         booking_day  journey_day  is_weekend  journey_month  \
# Class of Travel            0.013710    -0.007264   -0.009531      -0.000903
# Quota                     -0.007226     0.006755    0.004900      -0.004568
# Source Station             0.001582    -0.005997    0.005072      -0.000748
# Destination Station       -0.001038     0.011910    0.005101      -0.000888
# Current Status             0.003350    -0.017159   -0.009373       0.009844
# Number of Passengers       0.003229     0.009968    0.007485       0.001889
# Age of Passengers         -0.002187    -0.000858   -0.009244       0.003123
# Booking Channel           -0.004189     0.004025    0.002536      -0.005244
# Travel Distance            0.006307     0.000205    0.002707       0.005281
# Number of Stations         0.000150     0.004733    0.005277      -0.004045
# Travel Time                0.002706     0.010199    0.012414       0.000711
# Train Type                 0.000555     0.013891    0.005962      -0.009121
# Seat Availability         -0.003543    -0.000592    0.002860       0.007028
# Special Considerations     0.001672     0.006830    0.006259      -0.012988
# Holiday or Peak Season     0.014867    -0.002050    0.001007       0.000271
# Waitlist Position          0.004145    -0.008745   -0.007142       0.002211
# Confirmation Status        0.002990    -0.008768   -0.007717       0.007442
# year                      -0.000016     0.000072    0.000263       0.013760
# booking_day                1.000000    -0.248761   -0.271038       0.000174
# journey_day               -0.248761     1.000000    0.612372       0.000075
# is_weekend                -0.271038     0.612372    1.000000       0.000075
# journey_month              0.000174     0.000075    0.000075       1.000000
# days_to_travel             0.000082    -0.000128   -0.000096      -0.816610
#
#                         days_to_travel
# Class of Travel              -0.000174
# Quota                         0.000588
# Source Station                0.001022
# Destination Station           0.000654
# Current Status               -0.007790
# Number of Passengers         -0.001461
# Age of Passengers            -0.007675
# Booking Channel               0.001335
# Travel Distance              -0.002890
# Number of Stations            0.005066
# Travel Time                  -0.000950
# Train Type                    0.007595
# Seat Availability            -0.008375
# Special Considerations        0.013568
# Holiday or Peak Season        0.003763
# Waitlist Position            -0.000751
# Confirmation Status          -0.005934
# year                         -0.015785
# booking_day                   0.000082
# journey_day                  -0.000128
# is_weekend                   -0.000096
# journey_month                -0.816610
# days_to_travel                1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Class of Travel         30000 non-null  int32
#  1   Quota                   30000 non-null  int32
#  2   Source Station          30000 non-null  int32
#  3   Destination Station     30000 non-null  int32
#  4   Current Status          30000 non-null  int32
#  5   Number of Passengers    30000 non-null  int64
#  6   Age of Passengers       30000 non-null  int32
#  7   Booking Channel         30000 non-null  int32
#  8   Travel Distance         30000 non-null  int64
#  9   Number of Stations      30000 non-null  int64
#  10  Travel Time             30000 non-null  int64
#  11  Train Type              30000 non-null  int32
#  12  Seat Availability       30000 non-null  int64
#  13  Special Considerations  30000 non-null  int32
#  14  Holiday or Peak Season  30000 non-null  int32
#  15  Waitlist Position       30000 non-null  int32
#  16  Confirmation Status     30000 non-null  int32
#  17  year                    30000 non-null  int64
#  18  booking_day             30000 non-null  int32
#  19  journey_day             30000 non-null  int32
#  20  is_weekend              30000 non-null  int32
#  21  journey_month           30000 non-null  int32
#  22  days_to_travel          30000 non-null  int64
# dtypes: int32(16), int64(7)
# memory usage: 3.4 MB

# %% [markdown]
# # Dividing into Training and testing data

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(columns='Confirmation Status') #these will be our features
y=df['Confirmation Status'] #this is our target variable

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
X_train.shape
# Out:
# (24000, 22)

# %%
X_test.shape
# Out:
# (6000, 22)

# %%
y_train.shape
# Out:
# (24000,)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Class of Travel         30000 non-null  int32
#  1   Quota                   30000 non-null  int32
#  2   Source Station          30000 non-null  int32
#  3   Destination Station     30000 non-null  int32
#  4   Current Status          30000 non-null  int32
#  5   Number of Passengers    30000 non-null  int64
#  6   Age of Passengers       30000 non-null  int32
#  7   Booking Channel         30000 non-null  int32
#  8   Travel Distance         30000 non-null  int64
#  9   Number of Stations      30000 non-null  int64
#  10  Travel Time             30000 non-null  int64
#  11  Train Type              30000 non-null  int32
#  12  Seat Availability       30000 non-null  int64
#  13  Special Considerations  30000 non-null  int32
#  14  Holiday or Peak Season  30000 non-null  int32
#  15  Waitlist Position       30000 non-null  int32
#  16  Confirmation Status     30000 non-null  int32
#  17  year                    30000 non-null  int64
#  18  booking_day             30000 non-null  int32
#  19  journey_day             30000 non-null  int32
#  20  is_weekend              30000 non-null  int32
#  21  journey_month           30000 non-null  int32
#  22  days_to_travel          30000 non-null  int64
# dtypes: int32(16), int64(7)
# memory usage: 3.4 MB

# %% [markdown]
# # Applying PCA

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=5)
X_train = pca.fit_transform(X_train_scaled)
X_test= pca.transform(X_test_scaled)

# %% [markdown]
# #  Lets use different models and check which will be the best for prediction

# %% [markdown]
# # 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,f1_score

# %%
# Accuracy on training data
X_train_prediction=model.predict(X_train)
accuracy_score(X_train_prediction,y_train)
# Out:
# 1.0

# %%
# Accuracy on testing data
X_test_prediction=model.predict(X_test)
accuracy_score(X_test_prediction,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report, roc_auc_score
print(classification_report(y_test, y_pred))
print(roc_auc_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3980
#            1       1.00      1.00      1.00      2020
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000
#
# 1.0

# %% [markdown]
# # 2.Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier()

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf=rf_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred_rf)
# Out:
# 1.0

# %%
print(classification_report(y_test, y_pred_rf))
print(roc_auc_score(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3980
#            1       1.00      1.00      1.00      2020
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000
#
# 1.0

# %% [markdown]
# # 3.SVM

# %%
from sklearn.svm import SVC
svm_model=SVC()
svm_model.fit(X_train_scaled,y_train)
# Out:
# SVC()

# %%
y_pred_svm=svm_model.predict(X_test_scaled)

# %%
accuracy_score(y_test,y_pred_svm)
# Out:
# 1.0

# %% [markdown]
# #  4.KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model=KNeighborsClassifier()
knn_model.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn=knn_model.predict(X_test_scaled)

# %%
accuracy_score(y_test,y_pred_knn)
# Out:
# 0.9568333333333333
